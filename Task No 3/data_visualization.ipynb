# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_frame = pd.read_csv(r"C:\Users\Muneeb Iqbal\OneDrive\DEN Internship\Task 3\Placement_Data_Full_Class.csv")
data_frame = data_frame.set_index('sl_no')
data_frame
# Out:
#       gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# sl_no
# 1          M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 2          M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 3          M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 4          M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 5          M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
# 6          M  55.00   Others  49.80   Others   Science     67.25   Sci&Tech
# 7          F  46.00   Others  49.20   Others  Commerce     79.00  Comm&Mgmt
# 8          M  82.00  Central  64.00  Central   Science     66.00   Sci&Tech
# 9          M  73.00  Central  79.00  Central  Commerce     72.00  Comm&Mgmt
# 10         M  58.00  Central  70.00  Central  Commerce     61.00  Comm&Mgmt
# 11         M  58.00  Central  61.00  Central  Commerce     60.00  Comm&Mgmt
# 12         M  69.60  Central  68.40  Central  Commerce     78.30  Comm&Mgmt
# 13         F  47.00  Central  55.00   Others   Science     65.00  Comm&Mgmt
# 14         F  77.00  Central  87.00  Central  Commerce     59.00  Comm&Mgmt
# 15         M  62.00  Central  47.00  Central  Commerce     50.00  Comm&Mgmt
# 16         F  65.00  Central  75.00  Central  Commerce     69.00  Comm&Mgmt
# 17         M  63.00  Central  66.20  Central  Commerce     65.60  Comm&Mgmt
# 18         F  55.00  Central  67.00  Central  Commerce     64.00  Comm&Mgmt
# 19         F  63.00  Central  66.00  Central  Commerce     64.00  Comm&Mgmt
# 20         M  60.00   Others  67.00   Others      Arts     70.00  Comm&Mgmt
# 21         M  62.00   Others  65.00   Others  Commerce     66.00  Comm&Mgmt
# 22         F  79.00   Others  76.00   Others  Commerce     85.00  Comm&Mgmt
# 23         F  69.80   Others  60.80   Others   Science     72.23   Sci&Tech
# 24         F  77.40   Others  60.00   Others   Science     64.74   Sci&Tech
# 25         M  76.50   Others  97.70   Others   Science     78.86   Sci&Tech
# 26         F  52.58   Others  54.60  Central  Commerce     50.20  Comm&Mgmt
# 27         M  71.00   Others  79.00   Others  Commerce     66.00  Comm&Mgmt
# 28         M  63.00   Others  67.00   Others  Commerce     66.00  Comm&Mgmt
# 29         M  76.76   Others  76.50   Others  Commerce     67.50  Comm&Mgmt
# 30         M  62.00  Central  67.00  Central  Commerce     58.00  Comm&Mgmt
# 31         F  64.00  Central  73.50  Central  Commerce     73.00  Comm&Mgmt
# 32         F  67.00  Central  53.00  Central   Science     65.00   Sci&Tech
# 33         F  61.00  Central  81.00  Central  Commerce     66.40  Comm&Mgmt
# 34         F  87.00   Others  65.00   Others   Science     81.00  Comm&Mgmt
# 26       Yes    76.00        Mkt&Fin  65.33  Not Placed       0
# 27       Yes    94.00        Mkt&Fin  57.55      Placed  240000
# 28        No    68.00         Mkt&HR  57.69      Placed  265000
# 29       Yes    73.35        Mkt&Fin  64.15      Placed  350000
# 30        No    77.00        Mkt&Fin  51.29  Not Placed       0
# 31        No    52.00         Mkt&HR  56.70      Placed  250000
# 32        No    64.00         Mkt&HR  58.32  Not Placed       0
# 33        No    50.89         Mkt&HR  62.21      Placed  278000
# 34       Yes    88.00        Mkt&Fin  72.78      Placed  260000
# 35        No    68.44         Mkt&HR  62.77  Not Placed       0
# 36        No    71.00         Mkt&HR  62.74      Placed  300000
# 37        No    64.00        Mkt&Fin  51.45  Not Placed       0
# 38        No    58.00         Mkt&HR  55.47      Placed  320000
# 39        No    53.70         Mkt&HR  56.86      Placed  240000
# 40        No    93.00        Mkt&Fin  62.56      Placed  411000
# 41        No    60.00        Mkt&Fin  66.72      Placed  287000
# 42       Yes    65.00         Mkt&HR  69.76  Not Placed       0
# 43        No    63.00        Mkt&Fin  51.21  Not Placed       0
# 44        No    95.00         Mkt&HR  62.90      Placed  300000
# 45       Yes    89.00        Mkt&Fin  69.70      Placed  200000
# 46        No    58.00         Mkt&HR  66.53  Not Placed       0
# 47        No    68.00         Mkt&HR  71.63  Not Placed       0
# 48       Yes    78.00        Mkt&Fin  54.55      Placed  204000
# 49        No    64.00        Mkt&Fin  62.46      Placed  250000
# 50        No    65.00         Mkt&HR  56.11  Not Placed       0

# %%
data_frame['gender'].value_counts().plot(kind = 'pie', title = 'Gender Distribution', ylabel ='', autopct='%1.1f%%', startangle = 90, colors = ['lightblue', 'lightgreen'], figsize = (12,8))
# Out:
# <Axes: title={'center': 'Gender Distribution'}>

# %%
data_frame = data_frame.set_index('gender')
data_frame['salary'].plot(kind = 'barh', xlabel = 'salaries', ylabel = 'genders', figsize = (12,8))
# Out:
# <Axes: xlabel='salaries', ylabel='genders'>

# %%
plt.style.use('grayscale')
data_frame['status'].value_counts().plot(kind = 'bar', title = 'Placed vs Not Placed', xlabel = 'Status', ylabel ='Number of Students', figsize = (8,6))
# Out:
# <Axes: title={'center': 'Placed vs Not Placed'}, xlabel='Status', ylabel='Number of Students'>

# %%
data_frame.plot.scatter(x = 'degree_p', y = 'salary', title = 'Salary vs Degree Percentage', xlabel = 'Degree Percentage', ylabel ='Salary', figsize = (8,6))
# Out:
# <Axes: title={'center': 'Salary vs Degree Percentage'}, xlabel='Degree Percentage', ylabel='Salary'>

# %%
data_frame['hsc_s'].value_counts().plot(kind = 'bar', title = 'No of Students vs Major', xlabel = 'Major', ylabel ='Number of Students', color = 'lightgreen',figsize = (8,6))
# Out:
# <Axes: title={'center': 'No of Students vs Major'}, xlabel='Major', ylabel='Number of Students'>
